# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataza.csv')
df.head()
# Out:
#   ISO3       Location  DataId                   Indicator  Value  Precision  \
# 0  ZAF  Western  Cape  933882  Total fertility rate 15-49    2.3          1
# 1  ZAF   Eastern Cape  933876  Total fertility rate 15-49    3.5          1
# 2  ZAF  Northern Cape  917085  Total fertility rate 15-49    2.7          1
# 3  ZAF     Free State  925694  Total fertility rate 15-49    2.2          1
# 4  ZAF  KwaZulu Natal  925716  Total fertility rate 15-49    3.3          1
#
#   DHS_CountryCode   CountryName  SurveyYear   SurveyId  ... IsPreferred  \
# 0              ZA  South Africa        1998  ZA1998DHS  ...           1
# 1              ZA  South Africa        1998  ZA1998DHS  ...           1
# 2              ZA  South Africa        1998  ZA1998DHS  ...           1
# 3              ZA  South Africa        1998  ZA1998DHS  ...           1
# 4              ZA  South Africa        1998  ZA1998DHS  ...           1
#
#         SDRID         RegionId  SurveyYearLabel  SurveyType  \
# ...

# %%
df.describe()
# Out:
#              DataId       Value   Precision   SurveyYear  IndicatorOrder  \
# count  3.930000e+02  393.000000  393.000000   393.000000    3.930000e+02
# mean   3.226889e+06   50.166158    0.908397  2008.809160    9.740582e+07
# std    2.221997e+06   32.353246    0.288832     8.827526    6.510624e+07
# min    1.046160e+05    0.400000    0.000000  1998.000000    1.176308e+07
# 25%    9.260600e+05   18.400000    1.000000  1998.000000    5.170309e+07
# 50%    3.069675e+06   53.000000    1.000000  2016.000000    8.356607e+07
# 75%    5.218140e+06   79.700000    1.000000  2016.000000    1.355631e+08
# max    6.904978e+06   99.100000    1.000000  2016.000000    2.603210e+08
#
#        CharacteristicId  CharacteristicOrder  ByVariableId  IsTotal  \
# count        393.000000         3.930000e+02    393.000000    393.0
# mean      455005.045802         1.455005e+06   4168.389313      0.0
# std            2.590788         2.590788e+00   6410.370450      0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ISO3                    393 non-null    object
#  1   Location                393 non-null    object
#  2   DataId                  393 non-null    int64
#  3   Indicator               393 non-null    object
#  4   Value                   393 non-null    float64
#  5   Precision               393 non-null    int64
#  6   DHS_CountryCode         393 non-null    object
#  7   CountryName             393 non-null    object
#  8   SurveyYear              393 non-null    int64
#  9   SurveyId                393 non-null    object
#  10  IndicatorId             393 non-null    object
#  11  IndicatorOrder          393 non-null    int64
#  12  IndicatorType           393 non-null    object
#  13  CharacteristicId        393 non-null    int64
# ...

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='Location', hue='Indicator', palette='Set1')
plt.title('Counts of Different Indicators by Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Indicator', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\Tsako\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Tsako\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Tsako\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Create a stacked bar plot for indicators by location
plt.figure(figsize=(12, 8))
sns.histplot(data=df, x='Location', hue='Indicator', multiple='stack', palette='Set1')
plt.title('Stacked Bar Plot of Indicators by Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Indicator', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\Tsako\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Tsako\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Tsako\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# 3. Calculate and display average values by location and indicator
avg_values = df.groupby(['Location', 'Indicator'])['Value'].mean().unstack()
print("Average Values by Location and Indicator:")
print(avg_values)
# Out:
# Average Values by Location and Indicator:
# Indicator          Children stunted  Children underweight  Children wasted  \
# Location
# Eastern Cape                   24.8                   3.4              1.5
# Free State                     33.5                   8.0              4.6
# Gauteng                        34.2                   5.8              1.3
# KwaZulu Natal                  28.5                   3.8              2.5
# Mpumalanga                     21.5                   4.7              0.5
# North West                     27.4                  12.6              5.9
# Northern Cape                  21.4                   8.4              2.1
# Northern Province              21.9                   4.9              4.1
# Western  Cape                  22.9                  11.9              1.7
#
# Indicator          Demand for family planning satisfied by modern methods  \
# Location
# Eastern Cape                                                   71.55
# ...

# %%
# 4. Identify locations with the highest and lowest average values for a specific indicator
indicator_of_interest = 'Total fertility rate 15-49'
avg_values_for_indicator = avg_values[indicator_of_interest]
highest_location = avg_values_for_indicator.idxmax()
lowest_location = avg_values_for_indicator.idxmin()
print(f"For '{indicator_of_interest}':")
print(f"Highest Average Value Location: {highest_location} ({avg_values_for_indicator.max():.2f})")
print(f"Lowest Average Value Location: {lowest_location} ({avg_values_for_indicator.min():.2f})")
# Out:
# For 'Total fertility rate 15-49':
# Highest Average Value Location: Northern Province (3.50)
# Lowest Average Value Location: Western  Cape (2.20)
